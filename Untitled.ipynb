# %%
# Read in libraries needed for analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the data
df = pd.read_csv('FAOSTAT_trade_matrix.csv')

# %%
df
# Out:
#      Domain Code                 Domain  Reporter Country Code (M49)  \
# 0             TM  Detailed trade matrix                          250
# 1             TM  Detailed trade matrix                          250
# 2             TM  Detailed trade matrix                          250
# 3             TM  Detailed trade matrix                          250
# 4             TM  Detailed trade matrix                          250
# ...          ...                    ...                          ...
# 2555          TM  Detailed trade matrix                          528
# 2556          TM  Detailed trade matrix                          528
# 2557          TM  Detailed trade matrix                          528
# 2558          TM  Detailed trade matrix                          528
# 2559          TM  Detailed trade matrix                          528
#
#      Reporter Countries  Partner Country Code (M49) Partner Countries  \
# 0                France                         250            France
# 1                France                         250            France
# 2                France                         250            France
# 3                France                         250            France
# 4                France                         250            France
# ...                 ...                         ...               ...
# 2555        Netherlands                         380             Italy
# 2556        Netherlands                         380             Italy
# 2557        Netherlands                         380             Italy
# 2558        Netherlands                         380             Italy
# 2559        Netherlands                         380             Italy
#
#       Element Code          Element Item Code (CPC)  \
# 0             5910  Export Quantity           F0875
# 1             5910  Export Quantity           F0875
# 2             5910  Export Quantity           F0875
# 3             5910  Export Quantity           F0875
# 4             5910  Export Quantity           F0875
# ...            ...              ...             ...
# 2555          5922     Export Value           F0875
# 2556          5922     Export Value           F0875
# 2557          5922     Export Value           F0875
# 2558          5922     Export Value           F0875
# 2559          5922     Export Value           F0875
#
#                                 Item  Year Code  Year      Unit  Value Flag  \
# 0     beef and veal preparations nes       2000  2000    tonnes     23    A
# 1     beef and veal preparations nes       2001  2001    tonnes     52    A
# 2     beef and veal preparations nes       2002  2002    tonnes     74    A
# 3     beef and veal preparations nes       2003  2003    tonnes     52    A
# 4     beef and veal preparations nes       2004  2004    tonnes     45    A
# ...                              ...        ...   ...       ...    ...  ...
# 2555  beef and veal preparations nes       2016  2016  1000 US$   1122    A
# 2556  beef and veal preparations nes       2017  2017  1000 US$   3018    A
# 2557  beef and veal preparations nes       2018  2018  1000 US$   2081    A
# 2558  beef and veal preparations nes       2019  2019  1000 US$   2237    A
# 2559  beef and veal preparations nes       2020  2020  1000 US$   1213    A
#
#      Flag Description
# 0     Official figure
# 1     Official figure
# 2     Official figure
# 3     Official figure
# 4     Official figure
# ...               ...
# 2555  Official figure
# 2556  Official figure
# 2557  Official figure
# 2558  Official figure
# 2559  Official figure
#
# [2560 rows x 16 columns]

# %%
#Only keep the columns we want to use
df = df.iloc[:, [3,5,7,11,12,13]]

# %%
df
# Out:
#      Reporter Countries Partner Countries          Element  Year      Unit  \
# 0                France            France  Export Quantity  2000    tonnes
# 1                France            France  Export Quantity  2001    tonnes
# 2                France            France  Export Quantity  2002    tonnes
# 3                France            France  Export Quantity  2003    tonnes
# 4                France            France  Export Quantity  2004    tonnes
# ...                 ...               ...              ...   ...       ...
# 2555        Netherlands             Italy     Export Value  2016  1000 US$
# 2556        Netherlands             Italy     Export Value  2017  1000 US$
# 2557        Netherlands             Italy     Export Value  2018  1000 US$
# 2558        Netherlands             Italy     Export Value  2019  1000 US$
# 2559        Netherlands             Italy     Export Value  2020  1000 US$
#
#       Value
# 0        23
# 1        52
# 2        74
# 3        52
# 4        45
# ...     ...
# 2555   1122
# 2556   3018
# 2557   2081
# 2558   2237
# 2559   1213
#
# [2560 rows x 6 columns]

# %%
plt.title('Distribution of Values')
sns.swarmplot(data = df, x=df['Reporter Countries'], y=df['Value'], hue = 'Element')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0);
# Out:
# C:\Users\naomi\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 83.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\naomi\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\naomi\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 82.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\naomi\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 85.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\naomi\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 79.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Group the data by year and element
grouped = df.groupby(['Year', 'Element'])

# Define a function that sums up the values for each group
def sum_values(group):
    result = {
        'Year': group['Year'].iloc[0],
    }
    if 'Import Quantity' in group['Element'].iloc[0]:
        result['Import Quantity'] = group['Value'].sum()
        result['Import Country'] = group['Partner Countries'].iloc[0]
        
    if 'Import Value' in group['Element'].iloc[0]:
        result['Import Value'] = group['Value'].sum()
        result['Import Country'] = group['Partner Countries'].iloc[0]
        
    if 'Export Quantity' in group['Element'].iloc[0]:
        result['Export Quantity'] = group['Value'].sum()
        result['Export Country'] = group['Reporter Countries'].iloc[0]
        
    else:
        result['Export Value'] = group['Value'].sum()
        result['Export Country'] = group['Reporter Countries'].iloc[0]
    return result

# Apply the function to each group
results = [sum_values(group) for _, group in grouped]

# Convert the list of dictionaries into a DataFrame
result_df = pd.DataFrame.from_records(results)

# Reorder the columns to match the desired output
result_df = result_df[['Year', 'Import Quantity', 'Export Quantity', 'Import Country', 'Export Country', 'Import Value', 'Export Value']]

# Fill in any missing values with NaN
result_df = result_df.fillna(value=pd.np.nan)

# Display the resulting DataFrame
result_df
# Out:
# C:\Users\naomi\AppData\Local\Temp\ipykernel_15092\2641436165.py:36: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   result_df = result_df.fillna(value=pd.np.nan)
#      Year  Import Quantity  Export Quantity Import Country Export Country  \
# 0    1986              NaN            983.0            NaN         France
# 1    1986              NaN              NaN            NaN         France
# 2    1986           1393.0              NaN        Ireland         France
# 3    1986              NaN              NaN        Ireland         France
# 4    1987              NaN           1973.0            NaN         France
# ..    ...              ...              ...            ...            ...
# 135  2019              NaN              NaN        Germany         France
# 136  2020              NaN          44423.0            NaN         France
# 137  2020              NaN              NaN            NaN         France
# 138  2020          26257.0              NaN        Germany         France
# 139  2020              NaN              NaN        Germany         France
#
#      Import Value  Export Value
# 0             NaN           NaN
# 1             NaN        2554.0
# 2             NaN        1393.0
# 3          3727.0        3727.0
# 4             NaN           NaN
# ..            ...           ...
# 135      122438.0      122438.0
# 136           NaN           NaN
# 137           NaN      212716.0
# 138           NaN       26257.0
# 139      135894.0      135894.0
#
# [140 rows x 7 columns]

# %%
Target = 

if Target in CategoricalColumns:
    w1_value = ''
    w1 = None  
    w1 = widgets.Dropdown(
        options=[Target],
        value=Target,
        description='Target Variable:',
    )
    i = interactive(TargetAnalytics.custom_barplot, df=fixed(df), col1=w1)
    hbox = widgets.HBox(i.children[:1])
    display(hbox)
    hbox.on_displayed(TargetAnalytics.custom_barplot(df=df, col1=w1.value))
else:
    w1_value = ''
    w1 = None
    w1 = widgets.Dropdown(
            options=[Target],
            value=Target,
            description='Target Variable:',
        )
    i = interactive(NumericAnalytics.custom_barplot, df=fixed(df), col1=w1)
    hbox = widgets.HBox(i.children)
    display(hbox)
    hbox.on_displayed(NumericAnalytics.custom_barplot(df=df, col1=w1.value))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 if Target in CategoricalColumns:
#       2     w1_value = ''
#       3     w1 = None
#
# NameError: name 'Target' is not defined
